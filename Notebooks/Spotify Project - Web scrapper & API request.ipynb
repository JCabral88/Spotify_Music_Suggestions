# %% [markdown]
# # Song Recommender: Web scrapping & Spotify API
#
# #### Ironhack August 2022
#
# This project consists in creating a song recommender based on the audio features identified by Spotify. In this notebook, our main goal is to build two song databases (one for the Weekly  Hot 100 songs from Billboard, the other one from Kaggle), get the features for each song and create clusters to categorize and divide the songs.
#
# The following code is divided in two parts:
#
# - Web scrapping from Billboard Hot 100 and clean data from Kaggle dataset
# - Retrieving song IDs and features from Spotify

# %% [markdown]
# #### Libraries:

# %%
from functions import *
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import yaml

from config import *
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# Getting parameters from YAML file:

# %%
try: 
    with open ("params.yaml", 'r') as file:
        config = yaml.safe_load(file)
except Exception as e:
    print('Error reading the config file')

# %% [markdown]
# ## Web Scrapping and Data Cleaning

# %% [markdown]
# We'll start web scrapping the Billboard webpage in order to get the Top 100 Hot Songs. The function scrap_hot100 gets the url from the webpage as a parameter, creates a .csv file and returns the resulting dataframe.

# %%
hot_songs = scrap_hot100('https://www.billboard.com/charts/hot-100/')
hot_songs.head()
# Out:
#                                     title        artist
# 0                       Super Freaky Girl   Nicki Minaj
# 1                               As It Was  Harry Styles
# 2                         About Damn Time         Lizzo
# 3                           Break My Soul       Beyonce
# 4  Running Up That Hill (A Deal With God)     Kate Bush

# %% [markdown]
# Now, we're going to clean the dataset from Kaggle. We have selected a sample of 20.000 songs that after cleaning, we expect to work with a sample of 6.000 songs

# %%
not_hot_songs = NotHotSongs()
# Out:
# (5946, 2)
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot.drop(['user_id', 'song_id', 'listen_count', 'song'], axis = 1, inplace = True)
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot.drop_duplicates(inplace = True)
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:63: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nothot['title']= nothot['title'].str.replace('\\', '')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['title']= nothot['title'].str.replace('\\', '')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['title']= nothot['title'].str.replace('_', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['title']= nothot['title'].str.replace("'", "")
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['title'] = nothot['title'].str.replace(' /', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['title'] = nothot['title'].str.replace('/', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:69: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nothot['artist'] = nothot['artist'].str.replace('\\', '')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace('\\', '')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace('_', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace(' /', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace('/', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace(' Featuring', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace(' featuring', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace(' &', ',')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:76: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nothot['artist'] = nothot['artist'].str.replace('.', '')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace('.', '')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:77: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nothot['artist'] = nothot['artist'].str.replace('$', 's')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace('$', 's')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:78: FutureWarning: The default value of regex will change from True to False in a future version.
#   nothot['artist'] = nothot['artist'].str.replace('ft.', 'feat.')
# C:\Users\ameli\IRONHACK\WEEK_6\spotify_project\functions.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nothot['artist'] = nothot['artist'].str.replace('ft.', 'feat.')

# %%
print('Shape of the Kaggle dataframe is:', not_hot_songs.shape)
not_hot_songs.head()

# %% [markdown]
# # ----------------------------------------------------------------------------------------------------- #

# %% [markdown]
# # Spotify API request

# %% [markdown]
# Now we're going to connect with the Spotify API using the Spotipy library.
# This API has a requests rate limit, so we are going to split the data and run queries with a time interval of 30 seconds.

# %% [markdown]
# Introducing our credentials to connect with the Spotify API:

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id, client_secret= client_secret))

# %% [markdown]
# #### Popular songs dataset (100 Hot Billboard)
#
# Getting IDs and audio features of popular songs:

# %%
hot_songs = pd.read_csv(config['data']['hot_songs_file'])

# %% [markdown]
# Split data and get song IDs.

# %%
hot_songs_chunks = split_dataframe_by_position(hot_songs, 2)
hot_songs_ids = search_song(hot_songs_chunks)

# %% [markdown]
# Split data again and get song features.

# %%
hot_songs_ids_chunks = split_dataframe_by_position(hot_songs_ids, 2)
hot_songs_features = audio_features(hot_songs_ids_chunks, 'hot')

# %% [markdown]
# Create .cvs file with resulting dataframe.

# %%
hot_songs_features.head()
hot_songs_features.to_csv(config['data']['hot_songs_features'])

# %% [markdown]
# #### Not popular songs (Kaggle)
#
# Getting IDs and audio features of not so popular songs:

# %%
not_hot_songs = pd.read_csv(config['data']['not_hot_songs_file'])

# %% [markdown]
# Split data and get song IDs.

# %%
not_hot_songs_chunks = split_dataframe_by_position(not_hot_songs, 100)
not_hot_songs_ids = search_song(not_hot_songs_chunks)
# Out:
# 19, Song Television Rules The Nation, Crescendolls from Dafeat.Punk not found
# 26, Song Electric Avenue from Eddy Grant not found
# Out:
#    Unnamed: 0                 title                    artist  \
# 0      542811     Genie In A Bottle        Christina Aguilera
# 1     1015427  Swallowed In The Sea                  Coldplay
# 2       20039               We Ride                   Rihanna
# 3       96184             The Diary          Hollywood Undead
# 4      675997             Your Star  The All-American Rejects
#
#                        id                                               link  \
# 0  11mwFrKvLXCbcVGNxffGyP  https://open.spotify.com/artist/1l7ZsJRRS8wlW3...
# 1  2u2WL5N3KnQnykOZi3fxL6  https://open.spotify.com/artist/4gzpq5DPGxSnKT...
# 2  0EIsxWGPSte4cAHZw5aXr4  https://open.spotify.com/artist/5pKCCKE2ajJHZ9...
# 3  3D8fT4ExPoHvW6clW9nYLp  https://open.spotify.com/artist/0CEFCo8288kQU7...
# 4  1FiAliBdsh2bTWn4xHnbUG  https://open.spotify.com/artist/3vAaWhdBR38Q02...
#
#   danceability energy key loudness mode speechiness acousticness  \
# 0        0.633    0.8   1   -6.945    1       0.166        0.209
# 1        0.265  0.378  11  -10.823    1      0.0316       0.0557
# 2        0.394  0.744   5   -5.465    0       0.276      0.00175
# 3        0.612  0.666   0   -6.276    1      0.0363       0.0237
# 4         0.49  0.857   2   -3.641    1      0.0471     0.000785
#
#   instrumentalness liveness valence    tempo  \
# 0         0.000123    0.137   0.913  175.716
# 1         0.000001    0.119   0.153    142.1
# 2                0    0.308   0.772   78.696
# 3                0    0.662   0.788  148.064
# 4          0.00255   0.0953   0.483  148.072
#
#                                     uri  \
# 0  spotify:track:11mwFrKvLXCbcVGNxffGyP
# 1  spotify:track:2u2WL5N3KnQnykOZi3fxL6
# 2  spotify:track:0EIsxWGPSte4cAHZw5aXr4
# 3  spotify:track:3D8fT4ExPoHvW6clW9nYLp
# 4  spotify:track:1FiAliBdsh2bTWn4xHnbUG
#
#                                           track_href duration_ms   label
# 0  https://api.spotify.com/v1/tracks/11mwFrKvLXCb...      217573  nothot
# 1  https://api.spotify.com/v1/tracks/2u2WL5N3KnQn...      239002  nothot
# 2  https://api.spotify.com/v1/tracks/0EIsxWGPSte4...      236680  nothot
# 3  https://api.spotify.com/v1/tracks/3D8fT4ExPoHv...      275293  nothot
# 4  https://api.spotify.com/v1/tracks/1FiAliBdsh2b...      260827  nothot

# %% [markdown]
# Create .csv file with resulting dataframe.

# %%
not_hot_songs_features = not_hot_songs_features.drop('Unnamed: 0', axis=1)
not_hot_songs_features.to_csv(config['data']['not_hot_songs_features'])

# %% [markdown]
# ### Combine dataframes

# %%
combined_songs = pd.concat([hot_songs_features, not_hot_songs_features])
combined_songs = combined_songs.drop(['Unnamed: 0', 'link'], axis=1)
combined_songs.reset_index(drop=True).tail()
# Out:
#                      title                artist                      id  \
# 5617    Incident At Gate 7  Thievery Corporation  7dBAgPJ9krTupzldvpVnef
# 5618         Fire Eyed Boy   Broken Social Scene  3lAz9oK9c8BNeLQMK3mnlY
# 5619         Charmless Man                  Blur  7lJ9MeQgqHlBrE69omD4rN
# 5620  Communication Part 3      Armin van Buuren  0neva1N08tpWLLVrrXZm2Y
# 5621                   Rio           Duran Duran  43eBgYRTmu5BJnCJDBU5Hb
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 5617         0.735   0.454    6   -13.911     0       0.0627       0.00487
# 5618         0.431   0.940    9    -7.574     1       0.0425       0.00500
# 5619         0.535   0.876    9    -6.523     1       0.0418       0.00759
# 5620         0.567   0.702    1   -10.701     1       0.0393       0.00302
# 5621         0.544   0.873    9    -7.425     1       0.0525       0.04150
#
#       instrumentalness  liveness  valence    tempo  \
# 5617          0.898000    0.0510    0.400   99.999
# 5618          0.862000    0.2310    0.752  151.267
# 5619          0.000000    0.0350    0.846  116.766
# 5620          0.898000    0.0978    0.439  135.988
# 5621          0.000018    0.0925    0.676  140.902
#
#                                        uri  \
# 5617  spotify:track:7dBAgPJ9krTupzldvpVnef
# 5618  spotify:track:3lAz9oK9c8BNeLQMK3mnlY
# 5619  spotify:track:7lJ9MeQgqHlBrE69omD4rN
# 5620  spotify:track:0neva1N08tpWLLVrrXZm2Y
# 5621  spotify:track:43eBgYRTmu5BJnCJDBU5Hb
#
#                                              track_href  duration_ms   label
# 5617  https://api.spotify.com/v1/tracks/7dBAgPJ9krTu...       389413  nothot
# 5618  https://api.spotify.com/v1/tracks/3lAz9oK9c8BN...       238920  nothot
# 5619  https://api.spotify.com/v1/tracks/7lJ9MeQgqHlB...       213987  nothot
# 5620  https://api.spotify.com/v1/tracks/0neva1N08tpW...       507907  nothot
# 5621  https://api.spotify.com/v1/tracks/43eBgYRTmu5B...       337333  nothot

# %% [markdown]
# Create links to listen to the songs.

# %%
song_links = []

for i in combined_songs['id']:
    song_links.append('https://open.spotify.com/track/'+i)
    
combined_songs['links'] = song_links
# Out:
#                                        title                artist  \
# 0                          Super Freaky Girl           Nicki Minaj
# 1                                  As It Was          Harry Styles
# 2                            About Damn Time                 Lizzo
# 3                              Break My Soul               Beyonce
# 4     Running Up That Hill (A Deal With God)             Kate Bush
# ...                                      ...                   ...
# 5517                      Incident At Gate 7  Thievery Corporation
# 5518                           Fire Eyed Boy   Broken Social Scene
# 5519                           Charmless Man                  Blur
# 5520                    Communication Part 3      Armin van Buuren
# 5521                                     Rio           Duran Duran
#
#                           id  danceability  energy  key  loudness  mode  \
# 0     4C6Uex2ILwJi9sZXRdmqXp         0.950   0.891    2    -2.653     1
# 1     4LRPiXqCikLlN15c3yImP7         0.520   0.731    6    -5.338     0
# 2     1PckUlxKqWQs3RlWXVBLw3         0.836   0.743   10    -6.305     0
# 3     2KukL7UlQ8TdvpaA7bY3ZJ         0.687   0.887    1    -5.040     0
# 4     75FEaRjZTKLhTrFGsfMUXR         0.629   0.547   10   -13.123     0
# ...                      ...           ...     ...  ...       ...   ...
# 5517  7dBAgPJ9krTupzldvpVnef         0.735   0.454    6   -13.911     0
# 5518  3lAz9oK9c8BNeLQMK3mnlY         0.431   0.940    9    -7.574     1
# 5519  7lJ9MeQgqHlBrE69omD4rN         0.535   0.876    9    -6.523     1
# 5520  0neva1N08tpWLLVrrXZm2Y         0.567   0.702    1   -10.701     1
# 5521  43eBgYRTmu5BJnCJDBU5Hb         0.544   0.873    9    -7.425     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.2410       0.06450          0.000018    0.3090    0.912  133.010
# 1          0.0557       0.34200          0.001010    0.3110    0.662  173.930
# 2          0.0656       0.09950          0.000000    0.3350    0.722  108.966
# 3          0.0826       0.05750          0.000002    0.2700    0.853  114.941
# 4          0.0550       0.72000          0.003140    0.0604    0.197  108.375
# ...           ...           ...               ...       ...      ...      ...
# 5517       0.0627       0.00487          0.898000    0.0510    0.400   99.999
# 5518       0.0425       0.00500          0.862000    0.2310    0.752  151.267
# 5519       0.0418       0.00759          0.000000    0.0350    0.846  116.766
# 5520       0.0393       0.00302          0.898000    0.0978    0.439  135.988
# 5521       0.0525       0.04150          0.000018    0.0925    0.676  140.902
#
#                                        uri  \
# 0     spotify:track:4C6Uex2ILwJi9sZXRdmqXp
# 1     spotify:track:4LRPiXqCikLlN15c3yImP7
# 2     spotify:track:1PckUlxKqWQs3RlWXVBLw3
# 3     spotify:track:2KukL7UlQ8TdvpaA7bY3ZJ
# 4     spotify:track:75FEaRjZTKLhTrFGsfMUXR
# ...                                    ...
# 5517  spotify:track:7dBAgPJ9krTupzldvpVnef
# 5518  spotify:track:3lAz9oK9c8BNeLQMK3mnlY
# 5519  spotify:track:7lJ9MeQgqHlBrE69omD4rN
# 5520  spotify:track:0neva1N08tpWLLVrrXZm2Y
# 5521  spotify:track:43eBgYRTmu5BJnCJDBU5Hb
#
#                                              track_href  duration_ms   label  \
# 0     https://api.spotify.com/v1/tracks/4C6Uex2ILwJi...       170977     hot
# 1     https://api.spotify.com/v1/tracks/4LRPiXqCikLl...       167303     hot
# 2     https://api.spotify.com/v1/tracks/1PckUlxKqWQs...       191822     hot
# 3     https://api.spotify.com/v1/tracks/2KukL7UlQ8Td...       278282     hot
# 4     https://api.spotify.com/v1/tracks/75FEaRjZTKLh...       298933     hot
# ...                                                 ...          ...     ...
# 5517  https://api.spotify.com/v1/tracks/7dBAgPJ9krTu...       389413  nothot
# 5518  https://api.spotify.com/v1/tracks/3lAz9oK9c8BN...       238920  nothot
# 5519  https://api.spotify.com/v1/tracks/7lJ9MeQgqHlB...       213987  nothot
# 5520  https://api.spotify.com/v1/tracks/0neva1N08tpW...       507907  nothot
# 5521  https://api.spotify.com/v1/tracks/43eBgYRTmu5B...       337333  nothot
#
#                                                   links
# 0     https://open.spotify.com/track/4C6Uex2ILwJi9sZ...
# 1     https://open.spotify.com/track/4LRPiXqCikLlN15...
# 2     https://open.spotify.com/track/1PckUlxKqWQs3Rl...
# 3     https://open.spotify.com/track/2KukL7UlQ8Tdvpa...
# 4     https://open.spotify.com/track/75FEaRjZTKLhTrF...
# ...                                                 ...
# 5517  https://open.spotify.com/track/7dBAgPJ9krTupzl...
# 5518  https://open.spotify.com/track/3lAz9oK9c8BNeLQ...
# 5519  https://open.spotify.com/track/7lJ9MeQgqHlBrE6...
# 5520  https://open.spotify.com/track/0neva1N08tpWLLV...
# 5521  https://open.spotify.com/track/43eBgYRTmu5BJnC...
#
# [5622 rows x 19 columns]

# %%
combined_songs.to_csv(config['data']['combined_data'], index = False)
